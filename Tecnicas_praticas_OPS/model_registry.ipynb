# %% [markdown]
# ## Instalando o MLflow

# %%
# !pip install --user mlflow==2.2.2 -q
# Out:
#   WARNING: The script plasma_store.exe is installed in 'C:\Users\Renan Lemes\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] Acesso negado: 'C:\\Users\\Renan Lemes\\AppData\\Roaming\\Python\\Python39\\site-packages\\~yarrow\\arrow.dll'
# Check the permissions.

# %% [markdown]
# ## import das bibliotecas

# %%
import os
import mlflow
import numpy as np

# %% [markdown]
# ## Configurando o MLflow

# %%
MLFLOW_TRACKING_URI = ''
MLFLOW_TRACKING_USERNAME = ''
MLFLOW_TRACKING_PASSWORD = ''
os.environ['MLFLOW_TRACKING_USERNAME'] = MLFLOW_TRACKING_USERNAME
os.environ['MLFLOW_TRACKING_PASSWORD'] = MLFLOW_TRACKING_PASSWORD

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %% [markdown]
# ## Criando um client para comunicar com o registro no DagsHub

# %%
client = mlflow.MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
client

# %% [markdown]
# ## Recebendo o modelo registrado e suas versões

# %%
registered_model = client.get_registered_model('MODEL_NAME')
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# C:\Users\RENANL~1\AppData\Local\Temp/ipykernel_9496/3423969041.py in <module>
# ----> 1 registered_model = client.get_registered_model('MODEL_NAME')
#
# ~\AppData\Roaming\Python\Python39\site-packages\mlflow\tracking\client.py in get_registered_model(self, name)
#    2412             description: This sentiment analysis model classifies the tone-happy, sad, angry.
#    2413         """
# -> 2414         return self._get_registry_client().get_registered_model(name)
#    2415
#    2416     @deprecated(since="2.9.0", impact=_STAGES_DEPRECATION_WARNING)
#
# ~\AppData\Roaming\Python\Python39\site-packages\mlflow\tracking\_model_registry\client.py in get_registered_model(self, name)
#     120         :return: A single :py:class:`mlflow.entities.model_registry.RegisteredModel` object.
#     121         """
# --> 122         return self.store.get_registered_model(name)
#     123
#     124     def get_latest_versions(self, name, stages=None):
#
# ~\AppData\Roaming\Python\Python39\site-packages\mlflow\store\model_registry\file_store.py in get_registered_model(self, name)
#     371         model_path = self._get_registered_model_path(name)
#     372         if not exists(model_path):
# --> 373             raise MlflowException(
#     374                 f"Registered Model with name={name} not found",
#     375                 RESOURCE_DOES_NOT_EXIST,
#
# MlflowException: Registered Model with name=MODEL_NAME not found

# %%
registered_model.latest_versions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RENANL~1\AppData\Local\Temp/ipykernel_9496/1243459051.py in <module>
# ----> 1 registered_model.latest_versions
#
# NameError: name 'registered_model' is not defined

# %% [markdown]
# ## Obtendo o id da execução do modelo

# %%
run_id = registered_model.latest_versions[-1].run_id

# %% [markdown]
# ## Carregando o modelo

# %%
logged_model = f'runs:/{run_id}/model'
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %% [markdown]
# ## Fazendo uma predição com o modelo carregadO

# %%
accelerations = 0
fetal_movement = 0
uterine_contractions = 0
severe_decelerations = 0

# %%
received_data = np.array([
        accelerations,
        fetal_movement,
        uterine_contractions,
        severe_decelerations,
    ]).reshape(1, -1)

# %%
received_data

# %%
loaded_model.predict(received_data)
