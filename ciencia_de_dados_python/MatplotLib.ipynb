# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import load_iris
import seaborn as sns
iris = load_iris()

tips = sns.load_dataset("tips")
df = sns.load_dataset("penguins")
# Out:
# d:\Users\Renan Lemes\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
plt.figure()
plt.subplot(2, 1, 1) 
plt.plot(x, np.sin(x))
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))
plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))

# %%
fig, ax = plt.subplots(2)
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %%
fig, ax = plt.subplots(2, 3)
ax[0, 0].plot(x, np.sin(x))
ax[0, 1].plot(x, np.cos(x))
ax[0, 2].plot(x, np.sin(x)+0.5*np.cos(x))
ax[1, 0].plot(x, 0.5*np.sin(x)+np.cos(x))
ax[1, 1].plot(x, np.cos(x+1))
ax[1, 2].plot(x, np.sin(x+2))

# %% [markdown]
# ## Ajustando cor e estilo

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.sin(x-1))
plt.plot(x, np.sin(x-2))
plt.plot(x, np.sin(x-3)) #hexcode
plt.plot(x, np.sin(x-4))#rgb
plt.show()

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.sin(x-1))
plt.plot(x, np.sin(x-4))#rgb
plt.show()

# %%
plt.plot(x, np.sin(x), color='blue')
plt.plot(x, np.sin(x-1), color='g')
plt.plot(x, np.sin(x-2), color='0.7')
plt.plot(x, np.sin(x-3), color='#FFDD44') #hexcode
plt.plot(x, np.sin(x-4), color=(1, 0.2, 0.3)) #rgb
plt.show()

# %%
plt.plot(x, x+1, linestyle='solid')
plt.plot(x, x+2, linestyle='dashed')
plt.plot(x, x+3, linestyle='dashdot')
plt.plot(x, x+4, linestyle='dotted')
plt.show()

# %%
plt.plot(x, x+1, linestyle='-')
plt.plot(x, x+2, linestyle='--')
plt.plot(x, x+3, linestyle='-.')
plt.plot(x, x+4, linestyle=':')
plt.show()

# %%
plt.plot(x, x+1, '-g') #solido verde
plt.plot(x, x+2, '--c') #dashed ciano
plt.plot(x, x+3, '-.r') #dashdot vermelho
plt.plot(x, x+4, ':y') #dot amarelo
plt.show()

# %% [markdown]
# ## Ajustando eixos

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)
plt.show()

# %%
##invertendo

plt.plot(x, np.sin(x))
plt.xlim(11, -1)
plt.ylim(1.5, -1.5)
plt.show()

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5])
plt.show()

# %%
plt.plot(x, np.sin(x))
plt.axis('tight')
plt.show()

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Adicionando rotulos

# %%
plt.plot(x, np.sin(x))
plt.title('Seno')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend()
plt.show()

# %% [markdown]
# Alguns truques quando for usar axis
#
# plt.xlabel() -> ax.set_xlabel()
#
# plt.ylabel() -> ax.set_ylabel()
#
# plt.xlim() -> ax.set_xlim()
#
# plt.ylim() -> ax.set_ylim()
#
# plt.title() -> ax.set_title()

# %% [markdown]
# ## Scatter plot

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, 'o', color='black')
plt.show()

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
    label="marcador='{0}'".format(marker))
plt.legend()
plt.xlim(0, 2)
# Out:
# (0.0, 2.0)

# %%
plt.scatter(x, y, marker='o') #a diferença é que podemos controlar cada ponto do gráfico

# %%
rng = np.random.RandomState(20)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
cmap='viridis')
plt.colorbar()

# %%
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.2,
s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# ## Pizza

# %%
label = ['A', 'B', 'C']
valor = [0.5, 0.2, 0.3]

plt.pie(valor, labels=label)
plt.show()

# %% [markdown]
# ## Barra

# %%
conta = ['AAL', 'AAP', 'AAPL']
valores = {'open': [38.39, 132.44, 109.06],
          'low': [37.82, 131.04, 108.14]}

plt.bar(conta, valores['open'])
# Out:
# <BarContainer object of 3 artists>

# %%
conta = ['AAL', 'AAP', 'AAPL']
valores = {'open': [38.39, 132.44, 109.06],
          'low': [37.82, 131.04, 108.14]}


x_axis = np.arange(len(conta))
plt.bar(x_axis-0.2, valores['low'], 0.4, label='low')
plt.bar(x_axis+0.2, valores['open'], 0.4, label='open')
plt.xticks(x_axis, conta)
plt.show()

# %%
valores
# Out:
# {'open': [38.39, 132.44, 109.06], 'low': [37.82, 131.04, 108.14]}

# %%
bottom = np.zeros(3)
for label, weight in valores.items():
    plt.bar(conta, weight, 0.5, label=label, bottom = bottom)
    bottom += weight
plt.show()

# %% [markdown]
# ## Gráfico com intervalos

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k')
plt.show()

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
# define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)
# Compute the Gaussian process fit
gp = GaussianProcessRegressor()
gp.fit(xdata[:, np.newaxis], ydata)
xfit = np.linspace(0, 10, 1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis], return_std=True)
dyfit = 2 * MSE

# %%
plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')
plt.fill_between(xfit, yfit - dyfit, yfit + dyfit, color='gray', alpha=0.2)
#plt.xlim(0, 10)
plt.show()

# %% [markdown]
# ## Boxplot e violin

# %%
np.random.seed(15)
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]
plt.violinplot(all_data, showmeans=False,
                  showmedians=True)
plt.show()

# %%
plt.violinplot(all_data, showmeans=True,
                  showmedians=False)
plt.show()

# %%
plt.boxplot(all_data)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.violinplot([tips[tips.day=='Thur'].total_bill,
               tips[tips.day=='Fri'].total_bill,
              tips[tips.day=='Sat'].total_bill,
               tips[tips.day=='Sun'].total_bill])
plt.show()

# %% [markdown]
# ## Histograma

# %%
data = np.random.randn(1000)
plt.hist(data)
plt.show()

# %%
plt.hist(data, bins=30, alpha=0.5, color='steelblue', edgecolor='none')
plt.show()

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(alpha=0.3, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
plt.show()

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
plt.hist(df['flipper_length_mm'])
plt.show()

# %%
plt.hist(df[df.species=='Adelie'].flipper_length_mm, **kwargs)
plt.hist(df[df.species=='Chinstrap'].flipper_length_mm, **kwargs)
plt.hist(df[df.species=='Gentoo'].flipper_length_mm, **kwargs)
plt.show()

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('Frequência')

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='Frequência')

# %%
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)
x_hist.hist(x, 40, histtype='stepfilled', orientation='vertical', color='gray')
x_hist.invert_yaxis()
y_hist.hist(y, 40, histtype='stepfilled', orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %% [markdown]
# ## Plot de densidade e de contorno
#
# z = f(x,y)

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x
# Out:
# array([ 1.44873099, -1.10768633,  0.92713092, ..., -0.96517962,
#         0.30804282, -0.48550389])

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)

# %%
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black') #valores negativos são pontilhados

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy')

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy', alpha=0.5) #extent define o maximo e minimo
plt.colorbar()

# %% [markdown]
# ## Gráficos 3D

# %%
ax = plt.axes(projection='3d')
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')
plt.show()

# %%
ax = plt.axes(projection='3d')
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))
x = np.linspace(-6, 6, 50)
y = np.linspace(-6, 6, 50)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(60, 35)
