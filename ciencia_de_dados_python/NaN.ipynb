# %%
import numpy as np

# %%
array = np.array([1, 2, float('nan')])

# %%
array.dtype
# Out:
# dtype('float64')

# %%
np.sum(array)

# %%
np.nansum(array)

# %%
np.isnan(array)

# %%
array = np.array([1, 2, float('inf')])

# %%
np.sum(array)

# %%
np.isinf(array)
