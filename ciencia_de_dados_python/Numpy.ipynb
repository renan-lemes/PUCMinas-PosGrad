# %% [markdown]
# # Pacote Numpy

# %%
import numpy as np

# %% [markdown]
# ## Iniciando array

# %%
np.array([1, 2, 3])

# %%
np.array([[1, 2, 3], [4, 5, 6]])

# %%
np.zeros(10)

# %%
np.ones((3,5))

# %%
np.full((3, 5, 2), 2)

# %%
np.eye(3)

# %%
np.arange(0, 20)

# %%
np.arange(0, 20, 5)

# %%
np.linspace(0, 1, 5)

# %%
np.random.random((3, 4))

# %%
np.random.normal(0, 1, (4, 4))

# %%
np.random.randint(0, 10, (3, 3))

# %% [markdown]
# ## Dimensões de um array

# %%
a1 = np.random.randint(100, size=10)
a2 = np.random.randint(100, size=(3, 4))
a3 = np.random.randint(100, size=(3, 4, 5))

# %%
print(f'Número de dimensões: {a3.ndim}')
print(f'Formato das dimensões: {a3.shape}')
print(f'Número de valores no array: {a3.size}')
print(f'Tipo do dado: {a3.dtype}')

# %%
a1

# %%
a2

# %%
a3

# %% [markdown]
# ## Selecionando valores um único valor

# %%
a1

# %%
a1[1]

# %%
a1[-1]

# %%
## Em duas dimensões
a2

# %%
a2[0, 0]

# %%
a2[2, 0]

# %%
a2[2, -1]

# %%
a2[0, 0] = 80
a2

# %%
a2[0, 0] = 3.5
a2

# %%
## Em três dimensões
a3

# %%
a3[0, 0, 0]

# %%
a3[1, 0, 0]

# %%
a3[2, -1, 2]

# %% [markdown]
# ## Selecionando subarray

# %%
a1

# %%
a1[:2]

# %%
a1[5:]

# %%
a1[2:5]

# %%
a1[::3]

# %%
a1[::-1]

# %%
a1[5::-1]

# %%
a2

# %%
a2[0, :3]

# %%
a2[:2, :3]

# %%
a2[:2, ::2]

# %%
a2[::-1, ]

# %%
a2[::-1, ::-1]

# %%
a2[:, 0] #acessando primeira coluna

# %%
a2[0, :] #acessando a primeira linha

# %%
a2[0]

# %% [markdown]
# **SUBARRAY NÃO SÃO COPIAS**

# %%
lista = [1, 2, 3]

lista_sub = lista[:2]

# %%
lista_sub

# %%
lista[1] = 0
lista_sub

# %%
a2_sub = a2[:2, :2]

# %%
a2_sub

# %%
a2_sub[0, 0] = 8

# %%
a2

# %%
a2_sub = a2[:2, :2].copy()
a2_sub[0, 0] = 6
a2

# %% [markdown]
# ## Alterando as dimensões
# ### Reshape

# %%
a1 = np.arange(1, 10)
a1

# %%
a1.reshape((3, 3))

# %%
a1.reshape((3, 3, 1))

# %%
a1.reshape((1, 9)) #vetor linha

# %%
a1[np.newaxis, :]

# %%
a1[:, np.newaxis]

# %%
a2 = np.random.randint(100, size=(3, 4))
a2

# %% [markdown]
# ### Flatten

# %%
a2.flatten() #retorna uma copia

# %%
a2.ravel() #retorna uma view

# %%
a2.reshape((12, ))

# %% [markdown]
# ### Transpose

# %%
a2.T

# %%
np.transpose(a2)

# %% [markdown]
# ### Expand

# %%
a1

# %%
a1_row = np.expand_dims(a1, axis=0)
print(f'Número de dimensões: {a1_row.ndim}')
print(f'Formato das dimensões: {a1_row.shape}')
print(f'Número de valores no array: {a1_row.size}')
a1_row

# %%
a1_col = np.expand_dims(a1, axis=1)
print(f'Número de dimensões: {a1_col.ndim}')
print(f'Formato das dimensões: {a1_col.shape}')
print(f'Número de valores no array: {a1_col.size}')
a1_col

# %%
a2_0 = np.expand_dims(a2, axis=0)
print(f'Número de dimensões: {a2_0.ndim}')
print(f'Formato das dimensões: {a2_0.shape}')
print(f'Número de valores no array: {a2_0.size}')
a2_0

# %%
a2_1 = np.expand_dims(a2, axis=1)
print(f'Número de dimensões: {a2_1.ndim}')
print(f'Formato das dimensões: {a2_1.shape}')
print(f'Número de valores no array: {a2_1.size}')
a2_1

# %%
a2_3 = np.expand_dims(a2, axis=2)
print(f'Número de dimensões: {a2_3.ndim}')
print(f'Formato das dimensões: {a2_3.shape}')
print(f'Número de valores no array: {a2_3.size}')
a2_3

# %% [markdown]
# ### Squeeze

# %%
a1_row

# %%
a1_row.shape

# %%
a1_squeeze = np.squeeze(a1_row)

print(f'Número de dimensões: {a1_squeeze.ndim}')
print(f'Formato das dimensões: {a1_squeeze.shape}')
print(f'Número de valores no array: {a1_squeeze.size}')
a1_squeeze

# %%
a1_squeeze = np.squeeze(a1_row, axis=1)

# %%
a_new = np.array([[[1], [2], [3]]])
a_new

# %%
a_new.shape

# %%
np.squeeze(a_new, axis=0)

# %%
np.squeeze(a_new, axis=2)

# %%
np.squeeze(a_new, axis=2).shape

# %%
np.squeeze(a_new)

# %% [markdown]
# ## Algumas operações
# ### Concatenate

# %%
a1 = np.arange(1, 4)
a2 = np.arange(4, 7)

# %%
np.concatenate([a1, a2])

# %%
a3 = np.random.randint(10, size=(3,2))
a4 = np.random.randint(10, size=(2, 3))

# %%
np.concatenate([a1, a3])

# %%
np.concatenate([a3, a4])

# %%
a3

# %%
np.concatenate([a3, a3])

# %%
np.concatenate([a3, a3], axis=1)

# %%
a1

# %%
a4

# %%
np.vstack([a1, a4])

# %%
a3

# %%
np.expand_dims(a1, axis=1)

# %%
np.hstack([a3, np.expand_dims(a1, axis=1)])

# %%
np.hstack([np.expand_dims(a1, axis=1), a3])

# %% [markdown]
# ### Splitting

# %%
a1 = np.arange(0, 20, 2)
a1

# %%
np.split(a1, [3, 5])

# %%
a3

# %%
np.split(a3, [1], axis=1)

# %%
np.split(a3, [1], axis=0)

# %%
np.vsplit(a3, [1])

# %%
np.hsplit(a3, [1])

# %% [markdown]
# ## Funções aritméticas

# %%
x = np.arange(10)

# %%
np.add(x, 5)

# %%
np.add(x, x)

# %%
x + 5

# %%
x + x

# %%
x - 5

# %%
-x

# %%
x * 2

# %%
x / 2

# %%
x[1:] / x[1:]

# %%
x ** 2

# %%
np.absolute(x-5)

# %% [markdown]
# ## Funções trigonometricas

# %%
x = np.linspace(0, np.pi, 3)
x

# %%
np.cos(x)

# %%
np.sin(x)

# %%
x = np.arange(-1, 2)
x

# %%
np.arcsin(x)

# %%
np.arccos(x)

# %% [markdown]
# ## Logaritmo e exponencial

# %%
x = np.arange(1, 4)
x

# %%
np.exp(x)

# %%
np.power(3, x)

# %%
np.log(x)

# %%
np.log10(x)

# %% [markdown]
# ## Agregação

# %%
a1 = np.random.random((4, ))
a1

# %%
print(f'Soma: {np.sum(a1)}')
print(f'Produto: {np.prod(a1)}')
print(f'Média: {np.mean(a1)}')
print(f'Desvio padrao: {np.std(a1)}')
print(f'Variância: {np.var(a1)}')
print(f'Minimo: {np.min(a1)}')
print(f'Maximo: {np.max(a1)}')
print(f'Posição min: {np.argmin(a1)}')
print(f'Posição max: {np.argmax(a1)}')
print(f'Mediana: {np.median(a1)}')
print(f'Percentil 10: {np.percentile(a1, 10)}')
print(f'Percentil 50: {np.percentile(a1, 50)}')
print(f'Percentil 75: {np.percentile(a1, 75)}')

# %%
print(f'Soma acumulada: {np.cumsum(a1)}')
print(f'Produto acumulado: {np.cumprod(a1)}')

# %%
a1 = np.random.random((4, 3))
a1

# %%
a1.shape

# %%
print(f'Soma: {np.sum(a1)}')
print(f'Produto: {np.prod(a1)}')
print(f'Média: {np.mean(a1)}')
print(f'Desvio padrao: {np.std(a1)}')
print(f'Variância: {np.var(a1)}')
print(f'Minimo: {np.min(a1)}')
print(f'Maximo: {np.max(a1)}')
print(f'Posição min: {np.argmin(a1)}')
print(f'Posição max: {np.argmax(a1)}')
print(f'Mediana: {np.median(a1)}')
print(f'Percentil 10: {np.percentile(a1, 10)}')
print(f'Percentil 50: {np.percentile(a1, 50)}')
print(f'Percentil 75: {np.percentile(a1, 75)}')

# %%
print(f'Soma: {np.sum(a1, axis=0)}')
print(f'Produto: {np.prod(a1, axis=0)}')
print(f'Média: {np.mean(a1, axis=0)}')
print(f'Desvio padrao: {np.std(a1, axis=0)}')
print(f'Variância: {np.var(a1, axis=0)}')
print(f'Minimo: {np.min(a1, axis=0)}')
print(f'Maximo: {np.max(a1, axis=0)}')
print(f'Posição min: {np.argmin(a1, axis=0)}')
print(f'Posição max: {np.argmax(a1, axis=0)}')
print(f'Mediana: {np.median(a1, axis=0)}')
print(f'Percentil 10: {np.percentile(a1, 10, axis=0)}')
print(f'Percentil 50: {np.percentile(a1, 50, axis=0)}')
print(f'Percentil 75: {np.percentile(a1, 75, axis=0)}')

# %%
print(f'Soma: {np.sum(a1, axis=1)}')
print(f'Produto: {np.prod(a1, axis=1)}')
print(f'Média: {np.mean(a1, axis=1)}')
print(f'Desvio padrao: {np.std(a1, axis=1)}')
print(f'Variância: {np.var(a1, axis=1)}')
print(f'Minimo: {np.min(a1, axis=1)}')
print(f'Maximo: {np.max(a1, axis=1)}')
print(f'Posição min: {np.argmin(a1, axis=1)}')
print(f'Posição max: {np.argmax(a1, axis=1)}')
print(f'Mediana: {np.median(a1, axis=1)}')
print(f'Percentil 10: {np.percentile(a1, 10, axis=1)}')
print(f'Percentil 50: {np.percentile(a1, 50, axis=1)}')
print(f'Percentil 75: {np.percentile(a1, 75, axis=1)}')

# %% [markdown]
# ## Operação com matrizes

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

np.inner(x, y)

# %%
1 * 4 + 2 * 5 + 3 * 6

# %%
np.dot(x, y)

# %%
x = np.array([[1, 2], [3, 4]])
y = np.array([[5, 6], [7, 8]])

# %%
x

# %%
y

# %%
np.inner(x, y)

# %%
1 * 5 + 2 * 6

# %%
1 * 7 + 2* 8

# %%
np.dot(x, y)

# %%
1 * 5 + 2 * 7

# %%
1 * 6 + 2 * 8

# %%
square_matrix = np.arange(9).reshape((3,3))

# %%
square_matrix

# %%
square_matrix.trace()

# %%
square_matrix.diagonal()

# %%
np.linalg.det(square_matrix) ## matriz não inversivel

# %%
square_matrix = np.array([[2, 2, 1],
               [1, 3, 1],
               [1, 2, 2]])

# %%
np.linalg.det(square_matrix)

# %%
np.linalg.inv(square_matrix)

# %%
autovalor, autovetor = np.linalg.eig(square_matrix)

# %%
autovalor

# %%
autovetor
